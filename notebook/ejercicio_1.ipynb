# %%
# Ejercicios de practica 1


a= [3,2,1]
b= [1,2,3]
c=b
b=a
a=c

print(a,b)
# Out:
# [1, 2, 3] [3, 2, 1]

# %%
# Ejercicio de practica 2

a=121
b=77
c=110

n=3

total=a+b+c
dulces=total//n
residuo= total%n
print(total,dulces,residuo)
# Out:
# 308 102 2
