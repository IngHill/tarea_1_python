# %%
import sys
print(sys.path)
# Out:
# ['/home/juan/Documentos/notebook', '/home/juan/anaconda3/lib/python38.zip', '/home/juan/anaconda3/lib/python3.8', '/home/juan/anaconda3/lib/python3.8/lib-dynload', '', '/home/juan/anaconda3/lib/python3.8/site-packages', '/home/juan/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg', '/home/juan/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/home/juan/.ipython']

# %%
a = 1
